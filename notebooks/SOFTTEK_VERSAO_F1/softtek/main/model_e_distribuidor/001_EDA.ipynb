# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
caminho = os.path.join('..', '..', 'db_softtek') 
path_arq = os.path.abspath(caminho)

# %%
tbl_anl = pd.read_excel(path_arq+'\\cubo_anl\\tbl_full_analitica.xlsx')

# %%
#verificando se há valores nulos no data set:

tbl_anl.isnull().sum()
# Out:
# PROJETO                   0
# CHAMADO                   0
# Column1                   0
# DT_ABERTURA_CHAMADO       0
# MODULO_CHAMADO            0
# TIPO_CHAMADO              0
# STATUS_CHAMADO            0
# IS                        0
# CONSULTOR                 0
# MODULO_CustosNSULTOR      0
# EXERCICIO                 0
# PERIODO                   0
# DIA                       0
# HORAS                     0
# TIPO_HORAS                0
# COMPLEXIDADE              0
# NOME                      0
# CODIGO_AT                 0
# DESCRICAO_AT              0
# SENIORIDADE               0
# AUSENCIA_INI              0
# AUSENCIA_FIN              0
# AUSENCIA_TIPO             0
# VALOR_AT                  0
# DESCRICAO                 0
# TIPO_CONTRATO             0
# MODULO                    0
# TIPO_DEMANDA              0
# BASELINE                  0
# VALOR CONTRATO            0
# EXPERT                    0
# CUSTO_VENDA_EXPERT        0
# SENIOR                    0
# CUSTO_VENDA_SENIOR        0
# PLENO                     0
# CUSTO_VENDA_PLENO         0
# JUNIOR                    0
# CUSTO_VENDA_JUNIOR        0
# ESTAGIARIO                0
# CUSTO_VENDA_ESTAGIARIO    0
# HORAS_GESTAO              0
# CUSTO_VENDA_GESTAO        0
# INICIO_CONTRATO           0
# FIM_CONTRATO              0
# dtype: int64

# %%
tbl_anl.dtypes
# Out:
# PROJETO                           object
# CHAMADO                           object
# Column1                            int64
# DT_ABERTURA_CHAMADO               object
# MODULO_CHAMADO                    object
# TIPO_CHAMADO                      object
# STATUS_CHAMADO                    object
# IS                                object
# CONSULTOR                         object
# MODULO_CustosNSULTOR              object
# EXERCICIO                          int64
# PERIODO                            int64
# DIA                                int64
# HORAS                            float64
# TIPO_HORAS                        object
# COMPLEXIDADE                      object
# NOME                              object
# CODIGO_AT                         object
# DESCRICAO_AT                      object
# SENIORIDADE                       object
# AUSENCIA_INI                      object
# AUSENCIA_FIN                      object
# AUSENCIA_TIPO                     object
# VALOR_AT                         float64
# DESCRICAO                         object
# TIPO_CONTRATO                     object
# MODULO                            object
# TIPO_DEMANDA                      object
# BASELINE                           int64
# VALOR CONTRATO                     int64
# EXPERT                           float64
# CUSTO_VENDA_EXPERT               float64
# SENIOR                           float64
# CUSTO_VENDA_SENIOR               float64
# PLENO                            float64
# CUSTO_VENDA_PLENO                float64
# JUNIOR                           float64
# CUSTO_VENDA_JUNIOR               float64
# ESTAGIARIO                       float64
# CUSTO_VENDA_ESTAGIARIO           float64
# HORAS_GESTAO                     float64
# CUSTO_VENDA_GESTAO               float64
# INICIO_CONTRATO           datetime64[ns]
# FIM_CONTRATO              datetime64[ns]
# dtype: object

# %%
# tipando campos necessários:

tbl_anl['VALOR CONTRATO'] = tbl_anl['VALOR CONTRATO'].astype(float)

# %%
tbl_anl.describe()
# Out:
#           Column1  EXERCICIO     PERIODO         DIA       HORAS    VALOR_AT  \
# count  999.000000      999.0  999.000000  999.000000  999.000000  999.000000
# mean    10.310310     2024.0    1.972973   15.298298    2.383504   43.691570
# min      1.000000     2024.0    1.000000    1.000000    0.140000   13.636364
# 25%      2.000000     2024.0    1.000000    8.000000    0.700000   22.727273
# 50%      7.000000     2024.0    2.000000   15.000000    1.400000   36.363636
# 75%     14.000000     2024.0    3.000000   22.000000    2.800000   63.636364
# max     49.000000     2024.0    3.000000   31.000000   13.580000  100.000000
# std     10.712391        0.0    0.828035    8.353123    2.619132   24.861009
#
#          BASELINE  VALOR CONTRATO      EXPERT  CUSTO_VENDA_EXPERT  ...  \
# count  999.000000      999.000000  999.000000        9.990000e+02  ...
# mean   217.889890    14147.427427    0.038238        7.178000e+01  ...
# min     70.000000     1680.000000    0.000000        7.178000e+01  ...
# 25%    252.000000    16800.000000    0.000000        7.178000e+01  ...
# 50%    252.000000    16800.000000    0.000000        7.178000e+01  ...
# 75%    280.000000    19600.000000    0.100000        7.178000e+01  ...
# max    280.000000    19600.000000    0.100000        7.178000e+01  ...
# std     85.441538     7232.533191    0.048621        2.843595e-14  ...
#
#             PLENO  CUSTO_VENDA_PLENO      JUNIOR  CUSTO_VENDA_JUNIOR  \
# count  999.000000       9.990000e+02  999.000000              999.00
# mean     0.339740       5.313000e+01    0.198498               24.15
# min      0.000000       5.313000e+01    0.100000               24.15
# 25%      0.400000       5.313000e+01    0.100000               24.15
# 50%      0.400000       5.313000e+01    0.100000               24.15
# 75%      0.500000       5.313000e+01    0.100000               24.15
# max      0.500000       5.313000e+01    0.500000               24.15
# std      0.199077       7.108986e-15    0.172416                0.00
#
#        ESTAGIARIO  CUSTO_VENDA_ESTAGIARIO  HORAS_GESTAO  CUSTO_VENDA_GESTAO  \
# count  999.000000            9.990000e+02    999.000000              999.00
# mean     0.160260            1.449000e+01     32.683483               77.02
# min      0.000000            1.449000e+01     10.500000               77.02
# 25%      0.000000            1.449000e+01     37.800000               77.02
# 50%      0.100000            1.449000e+01     37.800000               77.02
# 75%      0.100000            1.449000e+01     42.000000               77.02
# max      0.500000            1.449000e+01     42.000000               77.02
# std      0.199077            1.777247e-15     12.816231                0.00
#
#            INICIO_CONTRATO         FIM_CONTRATO
# count                  999                  999
# mean   2024-01-01 00:00:00  2024-12-31 00:00:00
# min    2024-01-01 00:00:00  2024-12-31 00:00:00
# 25%    2024-01-01 00:00:00  2024-12-31 00:00:00
# 50%    2024-01-01 00:00:00  2024-12-31 00:00:00
# 75%    2024-01-01 00:00:00  2024-12-31 00:00:00
# max    2024-01-01 00:00:00  2024-12-31 00:00:00
# std                    NaN                  NaN
#
# [8 rows x 22 columns]

# %%
## Regras de negócio:

# 1 - Melhorar eficiencia em horas do volume de tratativas
# 2 - Melhorar a distribuição de demandas de acordo com o capacity de cada operador
# 3 - Melhorar a relação de custos de acordo com o capacity

# %%
tbl_anl.HORAS.plot(kind='box')
plt.title('Boxplot para a variavel horas')
plt.ylabel('tempo em horas')
plt.show()

# %%
# Solução para variável horas: Dividir em grupos de forma categorizada


# Função que verificaa o intervalo e retornar a marcação correspondente:

def verifica_intervalo(valor):
    if 0 < valor <= 2:
        return 'MAIOR que 0 e MENOR OU IGUAL a 2' # media
    elif 2 < valor <= 4:
        return 'MAIOR que 2 e MENOR OU IGUAL a 4' # media superior
    elif 4 < valor <= 6:
        return 'MAIOR que 4 e MENOR OU IGUAL a 6' # cauda
    elif valor > 6:
        return 'MAIOR que 6' # Outliers
    else:
        return 'fora dos intervalos' # dados invalidos


tbl_anl['intervalo_horas']= tbl_anl['HORAS'].apply(verifica_intervalo)

# %%
# validação da marcação:

tbl_anl[['HORAS','intervalo_horas']]
# Out:
#      HORAS                   intervalo_horas
# 0      2.8  MAIOR que 2 e MENOR OU IGUAL a 4
# 1      1.4  MAIOR que 0 e MENOR OU IGUAL a 2
# 2      0.7  MAIOR que 0 e MENOR OU IGUAL a 2
# 3      2.1  MAIOR que 2 e MENOR OU IGUAL a 4
# 4      4.2  MAIOR que 4 e MENOR OU IGUAL a 6
# ..     ...                               ...
# 994    0.7  MAIOR que 0 e MENOR OU IGUAL a 2
# 995    1.4  MAIOR que 0 e MENOR OU IGUAL a 2
# 996    1.4  MAIOR que 0 e MENOR OU IGUAL a 2
# 997    4.2  MAIOR que 4 e MENOR OU IGUAL a 6
# 998    4.2  MAIOR que 4 e MENOR OU IGUAL a 6
#
# [999 rows x 2 columns]

# %%
tbl_anl.VALOR_AT.plot(kind='hist',bins=10)
plt.axvline(tbl_anl.VALOR_AT.quantile(q=0.025), c='r')
plt.axvline(tbl_anl.VALOR_AT.quantile(q=0.975), c='r')    
plt.title('Histograma da variavel de Custos')
# Out:
# Text(0.5, 1.0, 'Histograma da variavel de Custos')

# %%
## Conclusão do histograma de valores: 

# Frequencia de valores acima de 97,5% é muito pequena (pode ser tratado de outra forma no modelo)

# %%
tbl_consultor = tbl_anl[tbl_anl['STATUS_CHAMADO'] == 'Closed']
tbl_consultor = tbl_consultor.groupby(['IS','MODULO_CHAMADO','TIPO_CHAMADO','MODULO_CustosNSULTOR','COMPLEXIDADE','SENIORIDADE']).agg(
    {'HORAS':'min','VALOR_AT':'min','CHAMADO':'count'}).reset_index()

# %%
tbl_consultor2 = tbl_consultor.groupby(['TIPO_CHAMADO','MODULO_CHAMADO','COMPLEXIDADE','IS','SENIORIDADE']).agg({'CHAMADO':'mean','HORAS':'min',
                                                                                         'VALOR_AT':'min'}).reset_index().sort_values(
                                                                                             ['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE',
                                                                                             'CHAMADO','HORAS','VALOR_AT'],
                                                                                               ascending=[True,True, True, False,True,True]
                                                                                               )
tbl_consultor2
# Out:
#     TIPO_CHAMADO MODULO_CHAMADO COMPLEXIDADE      IS SENIORIDADE  CHAMADO  \
# 1     Manutenção        Compras           N1    JDEF          Pr     13.0
# 2     Manutenção        Compras           N1    RBR1          Bg      8.0
# 3     Manutenção        Compras           N1    RTEC          Sr      4.0
# 4     Manutenção        Compras           N1  T3JFBD          Sr      2.0
# 0     Manutenção        Compras           N1    BMIR          Sr      2.0
# ..           ...            ...          ...     ...         ...      ...
# 130      Suporte         Vendas           N1    PMSN          Pr      1.0
# 132   Transporte          Infra           N2    FANT          Jr     12.0
# 134   Transporte          Infra           N2    IFGO          Bg     10.0
# 133   Transporte          Infra           N2    GRIA          Jr      2.0
# 135   Transporte          Infra           N2    WJMS          Pr      2.0
#
#      HORAS   VALOR_AT
# 1     0.70  36.363636
# 2     0.70  15.000000
# 3     0.70  63.636364
# 4     1.40  50.000000
# 0     1.40  63.636364
# ..     ...        ...
# 130   5.60  40.000000
# 132   0.70  22.727273
# 134   0.42  13.636364
# 133   0.42  22.727273
# 135   2.10  36.363636
#
# [136 rows x 8 columns]

# %%
# Normalizando as métricas de forma linear ponderada

tbl_consultor2['volume_normalizado'] = tbl_consultor2['CHAMADO'] / tbl_consultor2['CHAMADO'].max()

# Invertendo a normalização para que menor valor de horas por chamado seja melhor
tbl_consultor2['horas_normalizado'] = 1 - (tbl_consultor2['HORAS'] / tbl_consultor2['HORAS'].max())

# Invertendo a normalização para que menor valor de custo por chamado seja melhor
tbl_consultor2['custo_normalizado'] = 1 - (tbl_consultor2['VALOR_AT'] / tbl_consultor2['VALOR_AT'].max())

# %%
# Definindo os pesos para cada métrica:

peso_volume = 0.5
peso_horas = 0.3
peso_custo = 0.2

# %%
# Calculando o score de eficiência combinando os valores ponderados
tbl_consultor2['score_eficiencia'] = (
    (tbl_consultor2['volume_normalizado'] * peso_volume) + 
    (tbl_consultor2['horas_normalizado'] * peso_horas) + 
    (tbl_consultor2['custo_normalizado'] * peso_custo)
)

# %%
tbl_consultor3 = tbl_consultor2[['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE','IS','score_eficiencia','CHAMADO','SENIORIDADE']]
tbl_consultor3['rank'] = tbl_consultor3.groupby(['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE'])['score_eficiencia'].rank(ascending=False, method='dense')
tbl_consultor3.sort_values(['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE','rank'], inplace=True)

tbl_consultor3.head(50)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_16828\2075945244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tbl_consultor3['rank'] = tbl_consultor3.groupby(['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE'])['score_eficiencia'].rank(ascending=False, method='dense')
# C:\Users\andre\AppData\Local\Temp\ipykernel_16828\2075945244.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tbl_consultor3.sort_values(['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE','rank'], inplace=True)
#    TIPO_CHAMADO   MODULO_CHAMADO COMPLEXIDADE      IS  score_eficiencia  \
# 2    Manutenção          Compras           N1    RBR1          0.487553
# 1    Manutenção          Compras           N1    JDEF          0.471422
# 3    Manutenção          Compras           N1    RTEC          0.369004
# 4    Manutenção          Compras           N1  T3JFBD          0.360638
# 0    Manutenção          Compras           N1    BMIR          0.333366
# 5    Manutenção              Dev           N1    IFGO          0.460319
# 7    Manutenção              Dev           N1  T3TDAS          0.355319
# 6    Manutenção              Dev           N1    RNME          0.334236
# 12   Manutenção       Financeiro           N1    IFGO          0.468366
# 10   Manutenção       Financeiro           N1   GROD1          0.466779
# 8    Manutenção       Financeiro           N1    CJDA          0.431141
# 14   Manutenção       Financeiro           N1    MDSC          0.414507
# 11   Manutenção       Financeiro           N1    GUSB          0.413685
# 15   Manutenção       Financeiro           N1    PMSC          0.363685
# 17   Manutenção       Financeiro           N1  T3ASC4          0.359220
# 16   Manutenção       Financeiro           N1    RNME          0.291683
# 13   Manutenção       Financeiro           N1    JNIS          0.287911
# 9    Manutenção       Financeiro           N1    EDSR          0.284139
# 19   Manutenção       Financeiro           N2    IFGO          0.460319
# 20   Manutenção       Financeiro           N2    MTTA          0.369004
# 18   Manutenção       Financeiro           N2    EDSR          0.255319
# 24   Manutenção         Produção           N3  T3LSC2          0.449468
# 22   Manutenção         Produção           N3   GROD1          0.376596
# 23   Manutenção         Produção           N3    RNME          0.275319
# 21   Manutenção         Produção           N3     GLO          0.273501
# 28   Manutenção        Qualidade           N1  T3MSQ1          0.410957
# 26   Manutenção        Qualidade           N1    OTMD          0.370503
# 27   Manutenção        Qualidade           N1    RNME          0.291683
# 25   Manutenção        Qualidade           N1     GLO          0.273501
# 29   Manutenção           Vendas           N1   LFRO1          0.344004
# 30   Manutenção           Vendas           N1    SMMT          0.332640
# 31     Melhoria          Compras           N3    DDAS          0.360638
# 33     Melhoria          Compras           N3    JAMJ          0.354642
# 35     Melhoria          Compras           N3    RNME          0.291683
# 32     Melhoria          Compras           N3     GLO          0.273501
# 34     Melhoria          Compras           N3    RKEN          0.259865
# 36     Melhoria  Fluxo Aprovação           N3    RNME          0.275319
# 37     Melhoria  Fluxo Aprovação           N3  T3TDAS          0.271986
# 38     Melhoria         Produção           N3  T3LSC2          0.406915
# 40     Melhoria        Qualidade           N3    RTEC          0.352819
# 39     Melhoria        Qualidade           N3    BMIR          0.290319
# 41     Melhoria        Qualidade           N3    TSIA          0.202553
# 43     Melhoria           Vendas           N3    IFGO          0.460319
# 46     Melhoria           Vendas           N3   LFRO1          0.370600
# 45     Melhoria           Vendas           N3     LAS          0.345503
# 48     Melhoria           Vendas           N3    PMSN          0.330638
# 44     Melhoria           Vendas           N3     JVF          0.315319
# 47     Melhoria           Vendas           N3    MTTA          0.315319
# 49     Melhoria           Vendas           N3    SMMT          0.302321
# 42     Melhoria           Vendas           N3    AZBU          0.250319
#
#     CHAMADO SENIORIDADE  rank
# 2       8.0          Bg   1.0
# 1      13.0          Pr   2.0
# 3       4.0          Sr   3.0
# 4       2.0          Sr   4.0
# 0       2.0          Sr   5.0
# 5       1.0          Bg   1.0
# 7       1.0          Sr   2.0
# 6       9.0          Sr   3.0
# 12      2.0          Bg   1.0
# 10      7.0          Jr   2.0
# 8       5.0          Jr   3.0
# 14      7.0          Pr   4.0
# 11      3.0          Bg   5.0
# 15      3.0          Sr   6.0
# 17      8.0          Ex   7.0
# 16      1.0          Sr   8.0
# 13      2.0          Pr   9.0
# 9       3.0          Pr  10.0
# 19      1.0          Bg   1.0
# 20      4.0          Sr   2.0
# 18      1.0          Pr   3.0
# 24     14.0          Sr   1.0
# 22      5.0          Jr   2.0
# 23      1.0          Sr   3.0
# 21      1.0          Pr   4.0
# 28      3.0          Sr   1.0
# 26      3.0          Jr   2.0
# 27      1.0          Sr   3.0
# 25      1.0          Pr   4.0
# 29      4.0          Sr   1.0
# 30      4.0          Sr   2.0
# 31      2.0          Jr   1.0
# 33      6.0          Sr   2.0
# 35      1.0          Sr   3.0
# 32      1.0          Pr   4.0
# 34      1.0          Jr   5.0
# 36      1.0          Sr   1.0
# 37      1.0          Sr   2.0
# 38      6.0          Sr   1.0
# 40      1.0          Sr   1.0
# 39      1.0          Sr   2.0
# 41      8.0          Sr   3.0
# 43      1.0          Bg   1.0
# 46      9.0          Sr   2.0
# 45      3.0          Ex   3.0
# 48      2.0          Pr   4.0
# 44      1.0          Sr   5.0
# 47      1.0          Sr   5.0
# 49      3.0          Sr   6.0
# 42      1.0          Ex   7.0

# %%
''' Saída do modelo de score: '''

tbl_consultor4 = tbl_consultor3.groupby(['TIPO_CHAMADO','MODULO_CHAMADO','COMPLEXIDADE','IS']).agg({'rank':'min','score_eficiencia':'max'}).reset_index().sort_values(['TIPO_CHAMADO', 'MODULO_CHAMADO','COMPLEXIDADE','IS','rank']).drop_duplicates(subset='IS',keep='first')
tbl_consultor4.to_excel(path_arq+'\\modelo\\Modelo_score_train.xlsx',index=False)

# %%
tbl_consultor4.sort_values(['TIPO_CHAMADO','MODULO_CHAMADO','COMPLEXIDADE','rank'])
# Out:
#     TIPO_CHAMADO MODULO_CHAMADO COMPLEXIDADE      IS  rank  score_eficiencia
# 2     Manutenção        Compras           N1    RBR1   1.0          0.487553
# 1     Manutenção        Compras           N1    JDEF   2.0          0.471422
# 3     Manutenção        Compras           N1    RTEC   3.0          0.369004
# 4     Manutenção        Compras           N1  T3JFBD   4.0          0.360638
# 0     Manutenção        Compras           N1    BMIR   5.0          0.333366
# 5     Manutenção            Dev           N1    IFGO   1.0          0.460319
# 7     Manutenção            Dev           N1  T3TDAS   2.0          0.355319
# 6     Manutenção            Dev           N1    RNME   3.0          0.334236
# 10    Manutenção     Financeiro           N1   GROD1   2.0          0.466779
# 8     Manutenção     Financeiro           N1    CJDA   3.0          0.431141
# 14    Manutenção     Financeiro           N1    MDSC   4.0          0.414507
# 11    Manutenção     Financeiro           N1    GUSB   5.0          0.413685
# 15    Manutenção     Financeiro           N1    PMSC   6.0          0.363685
# 17    Manutenção     Financeiro           N1  T3ASC4   7.0          0.359220
# 13    Manutenção     Financeiro           N1    JNIS   9.0          0.287911
# 9     Manutenção     Financeiro           N1    EDSR  10.0          0.284139
# 20    Manutenção     Financeiro           N2    MTTA   2.0          0.369004
# 24    Manutenção       Produção           N3  T3LSC2   1.0          0.449468
# 21    Manutenção       Produção           N3     GLO   4.0          0.273501
# 28    Manutenção      Qualidade           N1  T3MSQ1   1.0          0.410957
# 26    Manutenção      Qualidade           N1    OTMD   2.0          0.370503
# 29    Manutenção         Vendas           N1   LFRO1   1.0          0.344004
# 30    Manutenção         Vendas           N1    SMMT   2.0          0.332640
# 31      Melhoria        Compras           N3    DDAS   1.0          0.360638
# 33      Melhoria        Compras           N3    JAMJ   2.0          0.354642
# 34      Melhoria        Compras           N3    RKEN   5.0          0.259865
# 41      Melhoria      Qualidade           N3    TSIA   3.0          0.202553
# 45      Melhoria         Vendas           N3     LAS   3.0          0.345503
# 48      Melhoria         Vendas           N3    PMSN   4.0          0.330638
# 44      Melhoria         Vendas           N3     JVF   5.0          0.315319
# 42      Melhoria         Vendas           N3    AZBU   7.0          0.250319
# 53        Perfis          Infra           N1    MIDS   2.0          0.929545
# 51        Perfis          Infra           N1    GRIA   3.0          0.483872
# 50        Perfis          Infra           N1    FANT   4.0          0.456141
# 55      Projetos     Financeiro           N3    RDRB   1.0          0.352553
# 57      Projetos         Fiscal           N3  T3TLGR   2.0          0.360638
# 60       Suporte             BI           N1   LFED2   2.0          0.357592
# 58       Suporte             BI           N1    FSIM   3.0          0.275319
# 61       Suporte             BI           N1    WPDM   3.0          0.275319
# 67       Suporte        Compras           N1   JMAP3   4.0          0.414507
# 72       Suporte        Compras           N1     VLU   8.0          0.344004
# 68       Suporte        Compras           N1   LGOM2  11.0          0.211277
# 82       Suporte         Custos           N3  T3CIBM   2.0          0.357624
# 81       Suporte         Custos           N3    MES1   5.0          0.101547
# 87       Suporte       Depósito           N1  T3JSM6   2.0          0.422872
# 89       Suporte     Financeiro           N1    CRSI   5.0          0.406141
# 88       Suporte     Financeiro           N1    ASGN   9.0          0.379642
# 101      Suporte     Financeiro           N1    RRLV  13.0          0.287911
# 96       Suporte     Financeiro           N1    JVM6  14.0          0.201547
# 104      Suporte     Financeiro           N3   MAPC5   1.0          0.370600
# 107      Suporte         Fiscal           N1    SVAS   2.0          0.318279
# 116      Suporte          Infra           N1    WJMS   5.0          0.368230
# 109      Suporte          Infra           N1    ESCM   6.0          0.349323
# 114      Suporte          Infra           N1    MGRK   7.0          0.328046
# 113      Suporte          Infra           N1    JOJC   8.0          0.241683
# 119      Suporte      Qualidade           N1     CTT   3.0          0.363685
# 129      Suporte         Vendas           N1   PFRN1   2.0          0.467553
# 124      Suporte         Vendas           N1   ARDA2   4.0          0.348549
# 128      Suporte         Vendas           N1    PCSF   6.0          0.283366
